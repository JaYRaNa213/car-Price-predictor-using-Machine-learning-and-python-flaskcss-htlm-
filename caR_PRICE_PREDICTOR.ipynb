# %%
import pandas as pd
import numpy as np

# %%
car= pd.read_csv("Quikr_car.csv")

# %%
car
# Out:
#       Unnamed: 0                                          Name     Label  \
# 0              0       Ford Figo Duratec Petrol EXI 1.2 - 2015  PLATINUM
# 1              1        Maruti Suzuki Wagon R VXI BS IV - 2016  PLATINUM
# 2              2  Hyundai Creta 1.6 SX PLUS AUTO PETROL - 2018  PLATINUM
# 3              3                          Hyundai Venue - 2019  PLATINUM
# 4              4                             Honda Jazz - 2017  PLATINUM
# ...          ...                                           ...       ...
# 1027        1027                  Hyundai i10 Magna 1.2 - 2014      GOLD
# 1028        1028         Maruti Suzuki Alto K10 LXi CNG - 2014      GOLD
# 1029        1029        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1030        1030        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1031        1031        Jeep Compass Limited 2.0 Diesel - 2017      GOLD
#
#         Location       Price   Kms_driven Fuel_type       Owner  Year  Company
# ...

# %%
car.shape
# Out:
# (1032, 10)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1032 entries, 0 to 1031
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1032 non-null   int64
#  1   Name        1032 non-null   object
#  2   Label       1032 non-null   object
#  3   Location    1030 non-null   object
#  4   Price       1032 non-null   object
#  5   Kms_driven  1032 non-null   object
#  6   Fuel_type   1032 non-null   object
#  7   Owner       740 non-null    object
#  8   Year        1032 non-null   int64
#  9   Company     1032 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 80.8+ KB

# %%
car['Year'].unique()
# Out:
# array([2015, 2016, 2018, 2019, 2017, 2013, 2012, 2020, 2014, 2011, 2021,
#        2010, 2001, 2022, 2000, 2008, 2005, 2007, 2006, 2004, 2002, 2009,
#        2003], dtype=int64)

# %%
#car['Price'].unique()

# %%
car.dropna(inplace=True)
car.isnull().sum()
# Out:
# Unnamed: 0    0
# Name          0
# Label         0
# Location      0
# Price         0
# Kms_driven    0
# Fuel_type     0
# Owner         0
# Year          0
# Company       0
# dtype: int64

# %%
car.drop('Owner',inplace=True,axis=1)

# %%
car
# Out:
#       Unnamed: 0                                            Name     Label  \
# 3              3                            Hyundai Venue - 2019  PLATINUM
# 4              4                               Honda Jazz - 2017  PLATINUM
# 5              5                              Hyundai i20 - 2013  PLATINUM
# 6              6  Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015  PLATINUM
# 7              7               Toyota Corolla Altis VL AT - 2017  PLATINUM
# ...          ...                                             ...       ...
# 1023        1023                         Ford Figo Aspire - 2017  PLATINUM
# 1027        1027                    Hyundai i10 Magna 1.2 - 2014      GOLD
# 1029        1029          Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1030        1030          Jeep Compass Limited 2.0 Diesel - 2017      GOLD
# 1031        1031          Jeep Compass Limited 2.0 Diesel - 2017      GOLD
#
#         Location       Price   Kms_driven Fuel_type  Year  Company
# ...

# %%
car['Year']=car['Year'].astype(int)

# %%
car['Price']=car['Price'].str.replace(',','')

# %%
car['Price']
# Out:
# 3       ₹1019699
# 4        ₹713499
# 5        ₹391099
# 6        ₹474299
# 7       ₹1252999
#           ...
# 1023     ₹481399
# 1027     ₹229000
# 1029    ₹1750000
# 1030    ₹1750000
# 1031    ₹1750000
# Name: Price, Length: 739, dtype: object

# %%
car['Price']=car['Price'].str.replace("₹","")

# %%
car=car[car['Price']!="Ask For Price"]
car.head()
# Out:
#    Unnamed: 0                                            Name     Label  \
# 3           3                            Hyundai Venue - 2019  PLATINUM
# 4           4                               Honda Jazz - 2017  PLATINUM
# 5           5                              Hyundai i20 - 2013  PLATINUM
# 6           6  Maruti Suzuki Swift Dzire VXi 1.2 BS IV - 2015  PLATINUM
# 7           7               Toyota Corolla Altis VL AT - 2017  PLATINUM
#
#   Location    Price   Kms_driven Fuel_type  Year  Company
# 3  Chennai  1019699  16,112 kms    Petrol   2019  Hyundai
# 4     Pune   713499  30,988 kms    Petrol   2017    Honda
# 5     Pune   391099  69,163 kms    Diesel   2013  Hyundai
# 6     Pune   474299  42,859 kms    Petrol   2015   Maruti
# 7     Pune  1252999  34,919 kms    Petrol   2017   Toyota

# %%
car['Price']
# Out:
# 3       1019699
# 4        713499
# 5        391099
# 6        474299
# 7       1252999
#          ...
# 1023     481399
# 1027     229000
# 1029    1750000
# 1030    1750000
# 1031    1750000
# Name: Price, Length: 737, dtype: object

# %%
car['Price']=car['Price'].astype('int64')
#car['Price'] = pd.to_numeric(car['Price'])
# Out:
# C:\Users\vsran\AppData\Local\Temp\ipykernel_7208\342293586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Price']=car['Price'].astype('int64')

# %%
car['Kms_driven']=car['Kms_driven'].str.replace(",","")
car['Kms_driven']=car['Kms_driven'].str.replace("kms","")
# Out:
# C:\Users\vsran\AppData\Local\Temp\ipykernel_7208\396817311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Kms_driven']=car['Kms_driven'].str.replace(",","")
# C:\Users\vsran\AppData\Local\Temp\ipykernel_7208\396817311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Kms_driven']=car['Kms_driven'].str.replace("kms","")

# %%
car['Kms_driven']=car['Kms_driven'].astype(int)
# Out:
# C:\Users\vsran\AppData\Local\Temp\ipykernel_7208\785220695.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Kms_driven']=car['Kms_driven'].astype(int)

# %%
car['Name']=car['Name'].str.split(' ').str.slice(0,3).str.join(' ')
# Out:
# C:\Users\vsran\AppData\Local\Temp\ipykernel_7208\1901955249.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car['Name']=car['Name'].str.split(' ').str.slice(0,3).str.join(' ')

# %%
car=car.reset_index(drop=True)

# %%
car.drop(['Label','Location','Unnamed: 0'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder ,StandardScaler
encoder=LabelEncoder()
car['Fuel_type']=encoder.fit_transform(car['Fuel_type'])

# %%
car=car[~car['Fuel_type'].isna()]

# %%
car['Fuel_type'].astype(int)
# Out:
# 0      4
# 1      4
# 2      1
# 3      4
# 4      4
#       ..
# 732    4
# 733    4
# 734    1
# 735    1
# 736    1
# Name: Fuel_type, Length: 737, dtype: int32

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        737 non-null    object
#  1   Price       737 non-null    int64
#  2   Kms_driven  737 non-null    int32
#  3   Fuel_type   737 non-null    int32
#  4   Year        737 non-null    int32
#  5   Company     737 non-null    object
# dtypes: int32(3), int64(1), object(2)
# memory usage: 26.0+ KB

# %%
car.describe()
# Out:
#               Price     Kms_driven   Fuel_type         Year
# count  7.370000e+02     737.000000  737.000000   737.000000
# mean   6.798567e+05   42865.037992    3.336499  2016.645862
# std    3.803285e+05   28514.239221    1.253554     2.299152
# min    7.300000e+04     700.000000    0.000000  2001.000000
# 25%    4.470990e+05   22667.000000    4.000000  2015.000000
# 50%    5.725990e+05   36277.000000    4.000000  2017.000000
# 75%    7.788880e+05   58492.000000    4.000000  2018.000000
# max    3.300000e+06  210000.000000    5.000000  2022.000000

# %%
car[car['Price']>6e6]
# Out:
# Empty DataFrame
# Columns: [Name, Price, Kms_driven, Fuel_type, Year, Company]
# Index: []

# %%
car.to_csv('clean_car.csv')

# %% [markdown]
# # Model

# %%
X=car.drop(columns='Price')
y=car['Price']

# %%
X
# Out:
#                      Name  Kms_driven  Fuel_type  Year  Company
# 0         Hyundai Venue -       16112          4  2019  Hyundai
# 1            Honda Jazz -       30988          4  2017    Honda
# 2           Hyundai i20 -       69163          1  2013  Hyundai
# 3     Maruti Suzuki Swift       42859          4  2015   Maruti
# 4    Toyota Corolla Altis       34919          4  2017   Toyota
# ..                    ...         ...        ...   ...      ...
# 732      Ford Figo Aspire       29632          4  2017     Ford
# 733     Hyundai i10 Magna       65000          4  2014  Hyundai
# 734  Jeep Compass Limited       31000          1  2017     Jeep
# 735  Jeep Compass Limited       31000          1  2017     Jeep
# 736  Jeep Compass Limited       31000          1  2017     Jeep
#
# [737 rows x 5 columns]

# %%
y
# Out:
# 0      1019699
# 1       713499
# 2       391099
# 3       474299
# 4      1252999
#         ...
# 732     481399
# 733     229000
# 734    1750000
# 735    1750000
# 736    1750000
# Name: Price, Length: 737, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

# %%
ohe=OneHotEncoder()

# %%
ohe.fit(X[['Name','Company','Fuel_type']])
# Out:
# OneHotEncoder()

# %%
ohe.categories_
# Out:
# [array(['Audi Q3 -', 'BMW 3 Series', 'BMW 5 Series', 'Chevrolet Sail 1.2',
#         'Datsun Redi GO', 'Fiat Linea Dynamic', 'Ford EcoSport -',
#         'Ford EcoSport Ambiente', 'Ford EcoSport Titanium',
#         'Ford Ecosport -', 'Ford Ecosport 1.0', 'Ford Endeavor 4X4',
#         'Ford Figo -', 'Ford Figo 1.5', 'Ford Figo Aspire',
#         'Ford Freestyle -', 'Honda Amaze -', 'Honda Amaze 1.2',
#         'Honda BRV -', 'Honda Brio -', 'Honda City -', 'Honda City 1.5',
#         'Honda City V', 'Honda City VX', 'Honda City ZX', 'Honda Jazz -',
#         'Honda Jazz 1.2', 'Honda WR V', 'Honda WRV VX', 'Hyundai Creta -',
#         'Hyundai Creta 1.6', 'Hyundai Creta S', 'Hyundai EON -',
#         'Hyundai EON D', 'Hyundai EON Era', 'Hyundai EON Magna',
#         'Hyundai Elite i20', 'Hyundai Eon Era', 'Hyundai Fluidic Verna',
#         'Hyundai Grand i10', 'Hyundai Santro 1.1', 'Hyundai Santro ASTA',
#         'Hyundai Santro Sportz', 'Hyundai Venue -', 'Hyundai Venue S',
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Name','Company','Fuel_type']),remainder='passthrough')

# %%
Lr= LinearRegression()

# %%
pipe=make_pipeline(column_trans,Lr)

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi Q3 -', 'BMW 3 Series', 'BMW 5 Series', 'Chevrolet Sail 1.2',
#        'Datsun Redi GO', 'Fiat Linea Dynamic', 'Ford EcoSport -',
#        'Ford EcoSport Ambiente', 'Ford EcoSport Titanium',
#        'Ford Ecosport -', 'Ford Ecosport 1.0', 'Ford Endeavor 4X4',
#        'For...
#        'Volkswagen Vento -', 'Volvo XC60 D3'], dtype=object),
#                                                                             array(['Audi', 'BMW', 'Chevrolet', 'Datsun', 'Fiat', 'Ford', 'Honda',
#        'Hyundai', 'Jaguar', 'Jeep', 'Kia', 'MG', 'Mahindra', 'Maruti',
#        'Mercedes', 'Nissan', 'Porsche', 'Renault', 'Skoda', 'Tata',
#        'Toyota', 'Volkswagen', 'Volvo'], dtype=object),
# ...

# %%
y_pred=pipe.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6888317394664853

# %%
scores=[]
for i in range(100):
    X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=i)
    Lr=LinearRegression()
    pipe=make_pipeline(column_trans,Lr)
    pipe.fit(X_train,y_train)
    y_pred=pipe.predict(X_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 41

# %%
scores[np.argmax(scores)]
# Out:
# 0.8282853641079332

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=np.argmax(scores))
Lr=LinearRegression()
pipe=make_pipeline(column_trans,Lr)
pipe.fit(X_train,y_train)
y_pred=pipe.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.8282853641079332

# %% [markdown]
# # Start the deployment of app

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
car_price=pipe.predict(pd.DataFrame([['Maruti Suzuki Swift','Maruti',2019,100,3]],columns=['Name','Company','Year','Kms_driven','Fuel_type']))

# %%
print(car_price)
# Out:
# [870825.02201846]
